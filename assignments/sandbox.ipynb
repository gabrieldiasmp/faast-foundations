# %%
import pandas as pd
import json

# %%
df = pd.read_csv('life_expectancy/data/eu_life_expectancy_raw.tsv',sep='\t')
print(df.head())
# Out:
#   unit,sex,age,geo\time 2021   2020   2019   2018   2017   2016   2015   \
# 0            YR,F,Y1,AL    :   79.4   80.4   80.2   79.7   79.8   79.2
# 1            YR,F,Y1,AM    :      :   79.1   79.2   78.5   78.0   77.9
# 2            YR,F,Y1,AT    :   82.9   83.5   83.3   83.2   83.4   83.0
# 3            YR,F,Y1,AZ    :      :   78.6   78.1   77.7      :   77.5
# 4            YR,F,Y1,BE    :   82.3   83.6   83.2   83.2   83.2   82.6
#
#    2014   2013   ...  1969   1968   1967   1966   1965   1964   1963   1962   \
# 0  79.8   79.6   ...     :      :      :      :      :      :      :      :
# 1     :      :   ...     :      :      :      :      :      :      :      :
# 2  83.3   83.0   ...     :      :      :      :      :      :      :      :
# 3  77.0   76.9   ...     :      :      :      :      :      :      :      :
# 4  83.1   82.5   ...  74.4   74.3   74.7   74.4   74.3   74.6   73.9   74.0
#
#    1961   1960
# 0     :      :
# 1     :      :
# 2     :      :
# 3     :      :
# 4  74.5   73.7
#
# [5 rows x 63 columns]

# %%
df.iloc[:, :5].head(14)
# Out:
#    unit,sex,age,geo\time 2021    2020      2019     2018
# 0             YR,F,Y1,AL    :    79.4      80.4     80.2
# 1             YR,F,Y1,AM    :       :      79.1     79.2
# 2             YR,F,Y1,AT    :    82.9      83.5     83.3
# 3             YR,F,Y1,AZ    :       :      78.6     78.1
# 4             YR,F,Y1,BE    :    82.3      83.6     83.2
# 5             YR,F,Y1,BG    :    76.9      78.2     78.0
# 6             YR,F,Y1,BY    :       :         :     78.7
# 7             YR,F,Y1,CH    :    84.4      85.1     85.0
# 8             YR,F,Y1,CY    :    83.5      83.6     83.9
# 9             YR,F,Y1,CZ    :    80.5      81.4     81.2
# 10            YR,F,Y1,DE    :    82.8      82.9     82.5
# 11        YR,F,Y1,DE_TOT    :    82.8      82.9     82.5
# 12            YR,F,Y1,DK    :    82.8      82.7     82.2
# 13          YR,F,Y1,EA18    :   83.4 p  84.2 bep  83.9 ep

# %%
## Save a sample of the raw data
df.iloc[:, :5].head(14).to_csv('life_expectancy/tests/fixtures/raw_data.tsv',sep='\t', index=False)

# %%
pd.DataFrame.from_dict(df.iloc[:, :5].head(14).to_dict())
# Out:
#    unit,sex,age,geo\time 2021    2020      2019     2018
# 0             YR,F,Y1,AL    :    79.4      80.4     80.2
# 1             YR,F,Y1,AM    :       :      79.1     79.2
# 2             YR,F,Y1,AT    :    82.9      83.5     83.3
# 3             YR,F,Y1,AZ    :       :      78.6     78.1
# 4             YR,F,Y1,BE    :    82.3      83.6     83.2
# 5             YR,F,Y1,BG    :    76.9      78.2     78.0
# 6             YR,F,Y1,BY    :       :         :     78.7
# 7             YR,F,Y1,CH    :    84.4      85.1     85.0
# 8             YR,F,Y1,CY    :    83.5      83.6     83.9
# 9             YR,F,Y1,CZ    :    80.5      81.4     81.2
# 10            YR,F,Y1,DE    :    82.8      82.9     82.5
# 11        YR,F,Y1,DE_TOT    :    82.8      82.9     82.5
# 12            YR,F,Y1,DK    :    82.8      82.7     82.2
# 13          YR,F,Y1,EA18    :   83.4 p  84.2 bep  83.9 ep

# %%
df = pd.DataFrame.from_dict(df.iloc[:, :5].head(14).to_dict())
df
# Out:
#    unit,sex,age,geo\time 2021    2020      2019     2018
# 0             YR,F,Y1,AL    :    79.4      80.4     80.2
# 1             YR,F,Y1,AM    :       :      79.1     79.2
# 2             YR,F,Y1,AT    :    82.9      83.5     83.3
# 3             YR,F,Y1,AZ    :       :      78.6     78.1
# 4             YR,F,Y1,BE    :    82.3      83.6     83.2
# 5             YR,F,Y1,BG    :    76.9      78.2     78.0
# 6             YR,F,Y1,BY    :       :         :     78.7
# 7             YR,F,Y1,CH    :    84.4      85.1     85.0
# 8             YR,F,Y1,CY    :    83.5      83.6     83.9
# 9             YR,F,Y1,CZ    :    80.5      81.4     81.2
# 10            YR,F,Y1,DE    :    82.8      82.9     82.5
# 11        YR,F,Y1,DE_TOT    :    82.8      82.9     82.5
# 12            YR,F,Y1,DK    :    82.8      82.7     82.2
# 13          YR,F,Y1,EA18    :   83.4 p  84.2 bep  83.9 ep

# %%
from life_expectancy.cleaning import clean_data

# %%
clean_data(life_expectancy_data=df, region="AT")
# Out:
# ----------- selected region: AT -----------
#   unit sex age region  year  value
# 0   YR   F  Y1     AT  2020   82.9
# 1   YR   F  Y1     AT  2019   83.5
# 2   YR   F  Y1     AT  2018   83.3

# %%
df[['unit', 'sex', 'age', 'region']] = df['unit,sex,age,geo\\time'].str.split(',', expand=True)

df.drop('unit,sex,age,geo\\time', axis=1, inplace=True)

df = pd.melt(df, id_vars=['unit', 'sex', 'age', 'region'], var_name="year")

df['value'].replace(': ', None, inplace=True)
df['value'] = df['value'].str.split(' ', expand=True)[0]

df['year'] = df['year'].astype(int)
df['value'] = df['value'].astype(float)

df = df.dropna()
df = df[df["region"] == "AT"]

#df.to_csv('life_expectancy/data/pt_life_expectancy.csv')

print(df)
# Out:
#    unit sex age region  year  value
# 7    YR   F  Y1     AT  2020   82.9
# 12   YR   F  Y1     AT  2019   83.5
# 17   YR   F  Y1     AT  2018   83.3

# %%
df.reset_index(drop=True).to_dict()
# Out:
# {'unit': {0: 'YR', 1: 'YR', 2: 'YR'},
#  'sex': {0: 'F', 1: 'F', 2: 'F'},
#  'age': {0: 'Y1', 1: 'Y1', 2: 'Y1'},
#  'region': {0: 'AT', 1: 'AT', 2: 'AT'},
#  'year': {0: 2020, 1: 2019, 2: 2018},
#  'value': {0: 82.9, 1: 83.5, 2: 83.3}}

# %%
df[df["value"].notnull()]
# Out:
#        unit sex    age region   year value
# 3418     YR   F    Y65     AT  2021   21.2
# 3420     YR   F    Y65     BE  2021   22.2
# 3421     YR   F    Y65     BG  2021   15.6
# 3423     YR   F    Y65     CH  2021   23.1
# 3424     YR   F    Y65     CY  2021   21.2
# ...     ...  ..    ...    ...    ...   ...
# 895735   YR   T  Y_LT1     EE  1960   69.4
# 895749   YR   T  Y_LT1     HU  1960   68.1
# 895762   YR   T  Y_LT1     NO  1960   73.8
# 895764   YR   T  Y_LT1     PT  1960   64.0
# 895770   YR   T  Y_LT1     SK  1960   70.3
#
# [474382 rows x 6 columns]

# %%
df['year'] = df['year'].astype(int)
df['value'] = df['value'].astype(float)

# %%
df = df.dropna()
df = df[df["region"] == "PT"]

# %%
df
# Out:
#        unit sex     age region  year  value
# 3460     YR   F     Y65     PT  2021   21.7
# 4804     YR   F   Y_LT1     PT  2021   84.3
# 8276     YR   M     Y65     PT  2021   17.8
# 9620     YR   M   Y_LT1     PT  2021   78.0
# 13092    YR   T     Y65     PT  2021   19.9
# ...     ...  ..     ...    ...   ...    ...
# 895540   YR   T     Y83     PT  1960    4.7
# 895596   YR   T     Y84     PT  1960    4.5
# 895652   YR   T      Y9     PT  1960   62.9
# 895708   YR   T  Y_GE85     PT  1960    4.2
# 895764   YR   T   Y_LT1     PT  1960   64.0
#
# [15744 rows x 6 columns]

# %%
df.to_csv('life_expectancy/data/pt_life_expectancy.csv')

# %%
import os
from life_expectancy.cleaning import load_data, clean_data, save_data, main

# %%
os.getcwd()
# Out:
# '/Users/gabrieldiasmp/Documents/pasta_gabriel/codigo/faast-foundations/assignments'

# %%
main(region="PT")
# Out:
# ----------- selected region: PT -----------
#        unit sex    age region   year value
# 0        YR   F     Y1     AL  2021   None
# 1        YR   F     Y1     AM  2021   None
# 2        YR   F     Y1     AT  2021   None
# 3        YR   F     Y1     AZ  2021   None
# 4        YR   F     Y1     BE  2021   None
# ...     ...  ..    ...    ...    ...   ...
# 895771   YR   T  Y_LT1     SM  1960   None
# 895772   YR   T  Y_LT1     TR  1960   None
# 895773   YR   T  Y_LT1     UA  1960   None
# 895774   YR   T  Y_LT1     UK  1960   None
# 895775   YR   T  Y_LT1     XK  1960   None
#
# [895776 rows x 6 columns]

# %%
life_expectancy = load_data(input_filename='/Users/gabrieldiasmp/Documents/pasta_gabriel/codigo/faast-foundations/assignments/life_expectancy/data/eu_life_expectancy_raw.tsv')

# %%
cleaned_life_expectancy = clean_data(life_expectancy, "PT")
# Out:
# ----------- selected region: PT -----------
#        unit sex    age region   year value
# 0        YR   F     Y1     AL  2021   None
# 1        YR   F     Y1     AM  2021   None
# 2        YR   F     Y1     AT  2021   None
# 3        YR   F     Y1     AZ  2021   None
# 4        YR   F     Y1     BE  2021   None
# ...     ...  ..    ...    ...    ...   ...
# 895771   YR   T  Y_LT1     SM  1960   None
# 895772   YR   T  Y_LT1     TR  1960   None
# 895773   YR   T  Y_LT1     UA  1960   None
# 895774   YR   T  Y_LT1     UK  1960   None
# 895775   YR   T  Y_LT1     XK  1960   None
#
# [895776 rows x 6 columns]

# %%
cleaned_life_expectancy
# Out:
#        unit sex     age region  year  value
# 3460     YR   F     Y65     PT  2021   21.7
# 4804     YR   F   Y_LT1     PT  2021   84.3
# 8276     YR   M     Y65     PT  2021   17.8
# 9620     YR   M   Y_LT1     PT  2021   78.0
# 13092    YR   T     Y65     PT  2021   19.9
# ...     ...  ..     ...    ...   ...    ...
# 895540   YR   T     Y83     PT  1960    4.7
# 895596   YR   T     Y84     PT  1960    4.5
# 895652   YR   T      Y9     PT  1960   62.9
# 895708   YR   T  Y_GE85     PT  1960    4.2
# 895764   YR   T   Y_LT1     PT  1960   64.0
#
# [15744 rows x 6 columns]

# %%
life_expectancy[['unit', 'sex', 'age', 'region']] = \
    life_expectancy['unit,sex,age,geo\\time'].str.split(',', expand=True)

# Dropping the conjugated column
life_expectancy.drop('unit,sex,age,geo\\time', axis=1, inplace=True)

# From wide to long
life_expectancy = pd.melt(
    life_expectancy,
    id_vars=['unit', 'sex', 'age', 'region'],
    var_name="year"
)

# %%
life_expectancy['value'].replace(': ', None, inplace=True)

# %%
life_expectancy['value'] = life_expectancy['value'].str.split(' ', expand=True)[0]
life_expectancy
# Out:
#        unit sex    age region   year value
# 0        YR   F     Y1     AL  2021   None
# 1        YR   F     Y1     AM  2021   None
# 2        YR   F     Y1     AT  2021   None
# 3        YR   F     Y1     AZ  2021   None
# 4        YR   F     Y1     BE  2021   None
# ...     ...  ..    ...    ...    ...   ...
# 895771   YR   T  Y_LT1     SM  1960   None
# 895772   YR   T  Y_LT1     TR  1960   None
# 895773   YR   T  Y_LT1     UA  1960   None
# 895774   YR   T  Y_LT1     UK  1960   None
# 895775   YR   T  Y_LT1     XK  1960   None
#
# [895776 rows x 6 columns]

# %%
life_expectancy['value'] = life_expectancy['value'].astype(float)

# %% [markdown]
# - Test with fixtures

# %%
from life_expectancy.cleaning import load_data, clean_data, save_data, main

# %%
def life_expectancy_expected() -> pd.DataFrame:
    """Fixture to load the expected output of the cleaning script"""

    df_dict = {
        'unit': {0: 'YR', 1: 'YR', 2: 'YR'},
        'sex': {0: 'F', 1: 'F', 2: 'F'},
        'age': {0: 'Y1', 1: 'Y1', 2: 'Y1'},
        'region': {0: 'AT', 1: 'AT', 2: 'AT'},
        'year': {0: 2020, 1: 2019, 2: 2018},
        'value': {0: 82.9, 1: 83.5, 2: 83.3}
    }

    df_expected = pd.DataFrame.from_dict(data = df_dict)

    return df_expected

life_expectancy_expected = life_expectancy_expected()

# %%
life_expectancy_expected
# Out:
#   unit sex age region  year  value
# 0   YR   F  Y1     AT  2020   82.9
# 1   YR   F  Y1     AT  2019   83.5
# 2   YR   F  Y1     AT  2018   83.3

# %%
df_load = load_data(
    '/Users/gabrieldiasmp/Documents/pasta_gabriel/codigo/faast-foundations/assignments/life_expectancy/tests/fixtures/raw_data.tsv'
    )

df_load
# Out:
#   unit,sex,age,geo\time 2021   2020   2019   2018
# 0            YR,F,Y1,AL    :   79.4    80.4   80.2
# 1            YR,F,Y1,AM    :      :    79.1   79.2
# 2            YR,F,Y1,AT    :   82.9    83.5   83.3
# 3            YR,F,Y1,AZ    :      :    78.6   78.1
# 4            YR,F,Y1,BE    :   82.3    83.6   83.2

# %%
df_clean = clean_data(df_load, region="AT")
df_clean
# Out:
# ----------- selected region: AT -----------
#   unit sex age region  year  value
# 0   YR   F  Y1     AT  2020   82.9

# %%
life_expectancy = df_load.copy()

# Splitting a conjugated column in multiple column
life_expectancy[['unit', 'sex', 'age', 'region']] = \
    life_expectancy['unit,sex,age,geo\\time'].str.split(',', expand=True)

# Dropping the conjugated column
life_expectancy.drop('unit,sex,age,geo\\time', axis=1, inplace=True)

# From wide to long
life_expectancy = pd.melt(
    life_expectancy,
    id_vars=['unit', 'sex', 'age', 'region'],
    var_name="year"
)

life_expectancy
# Out:
#    unit sex age region   year  value
# 0    YR   F  Y1     AL  2021      :
# 1    YR   F  Y1     AM  2021      :
# 2    YR   F  Y1     AT  2021      :
# 3    YR   F  Y1     AZ  2021      :
# 4    YR   F  Y1     BE  2021      :
# 5    YR   F  Y1     AL  2020   79.4
# 6    YR   F  Y1     AM  2020      :
# 7    YR   F  Y1     AT  2020   82.9
# 8    YR   F  Y1     AZ  2020      :
# 9    YR   F  Y1     BE  2020   82.3
# 10   YR   F  Y1     AL  2019    80.4
# 11   YR   F  Y1     AM  2019    79.1
# 12   YR   F  Y1     AT  2019    83.5
# 13   YR   F  Y1     AZ  2019    78.6
# 14   YR   F  Y1     BE  2019    83.6
# 15   YR   F  Y1     AL  2018    80.2
# 16   YR   F  Y1     AM  2018    79.2
# 17   YR   F  Y1     AT  2018    83.3
# 18   YR   F  Y1     AZ  2018    78.1
# 19   YR   F  Y1     BE  2018    83.2

# %%
# Cleaning values that were supposed to be null and values with strings attached
life_expectancy['value'].replace(': ', None, inplace=True)
life_expectancy
# Out:
#    unit sex age region   year  value
# 0    YR   F  Y1     AL  2021    None
# 1    YR   F  Y1     AM  2021    None
# 2    YR   F  Y1     AT  2021    None
# 3    YR   F  Y1     AZ  2021    None
# 4    YR   F  Y1     BE  2021    None
# 5    YR   F  Y1     AL  2020   79.4
# 6    YR   F  Y1     AM  2020    None
# 7    YR   F  Y1     AT  2020   82.9
# 8    YR   F  Y1     AZ  2020    None
# 9    YR   F  Y1     BE  2020   82.3
# 10   YR   F  Y1     AL  2019    80.4
# 11   YR   F  Y1     AM  2019    79.1
# 12   YR   F  Y1     AT  2019    83.5
# 13   YR   F  Y1     AZ  2019    78.6
# 14   YR   F  Y1     BE  2019    83.6
# 15   YR   F  Y1     AL  2018    80.2
# 16   YR   F  Y1     AM  2018    79.2
# 17   YR   F  Y1     AT  2018    83.3
# 18   YR   F  Y1     AZ  2018    78.1
# 19   YR   F  Y1     BE  2018    83.2

# %%
life_expectancy.dropna()
# Out:
#    unit sex age region   year  value
# 5    YR   F  Y1     AL  2020   79.4
# 7    YR   F  Y1     AT  2020   82.9
# 9    YR   F  Y1     BE  2020   82.3
# 10   YR   F  Y1     AL  2019    80.4
# 11   YR   F  Y1     AM  2019    79.1
# 12   YR   F  Y1     AT  2019    83.5
# 13   YR   F  Y1     AZ  2019    78.6
# 14   YR   F  Y1     BE  2019    83.6
# 15   YR   F  Y1     AL  2018    80.2
# 16   YR   F  Y1     AM  2018    79.2
# 17   YR   F  Y1     AT  2018    83.3
# 18   YR   F  Y1     AZ  2018    78.1
# 19   YR   F  Y1     BE  2018    83.2

# %%
life_expectancy['value'] = life_expectancy['value'].str.split(' ', expand=True)[0]
life_expectancy
# Out:
#    unit sex age region   year value
# 0    YR   F  Y1     AL  2021   None
# 1    YR   F  Y1     AM  2021   None
# 2    YR   F  Y1     AT  2021   None
# 3    YR   F  Y1     AZ  2021   None
# 4    YR   F  Y1     BE  2021   None
# 5    YR   F  Y1     AL  2020   79.4
# 6    YR   F  Y1     AM  2020   None
# 7    YR   F  Y1     AT  2020   82.9
# 8    YR   F  Y1     AZ  2020   None
# 9    YR   F  Y1     BE  2020   82.3
# 10   YR   F  Y1     AL  2019    NaN
# 11   YR   F  Y1     AM  2019    NaN
# 12   YR   F  Y1     AT  2019    NaN
# 13   YR   F  Y1     AZ  2019    NaN
# 14   YR   F  Y1     BE  2019    NaN
# 15   YR   F  Y1     AL  2018    NaN
# 16   YR   F  Y1     AM  2018    NaN
# 17   YR   F  Y1     AT  2018    NaN
# 18   YR   F  Y1     AZ  2018    NaN
# 19   YR   F  Y1     BE  2018    NaN

# %%
life_expectancy
# Out:
#    unit sex age region   year value
# 0    YR   F  Y1     AL  2021   None
# 1    YR   F  Y1     AM  2021   None
# 2    YR   F  Y1     AT  2021   None
# 3    YR   F  Y1     AZ  2021   None
# 4    YR   F  Y1     BE  2021   None
# 5    YR   F  Y1     AL  2020   79.4
# 6    YR   F  Y1     AM  2020   None
# 7    YR   F  Y1     AT  2020   82.9
# 8    YR   F  Y1     AZ  2020   None
# 9    YR   F  Y1     BE  2020   82.3
# 10   YR   F  Y1     AL  2019    NaN
# 11   YR   F  Y1     AM  2019    NaN
# 12   YR   F  Y1     AT  2019    NaN
# 13   YR   F  Y1     AZ  2019    NaN
# 14   YR   F  Y1     BE  2019    NaN
# 15   YR   F  Y1     AL  2018    NaN
# 16   YR   F  Y1     AM  2018    NaN
# 17   YR   F  Y1     AT  2018    NaN
# 18   YR   F  Y1     AZ  2018    NaN
# 19   YR   F  Y1     BE  2018    NaN

# %%
# Changing column types
life_expectancy['year'] = life_expectancy['year'].astype(int)
life_expectancy['value'] = life_expectancy['value'].astype(float)

# Filtering observations of a specific region
life_expectancy = life_expectancy[life_expectancy["region"] == region]

# Dropping rows that contain null values
life_expectancy = life_expectancy.dropna()

# %% [markdown]
# - Import json

# %%
path = "/Users/gabrieldiasmp/Documents/pasta_gabriel/codigo/faast-foundations/assignments/life_expectancy/data/eurostat_life_expect.json"
with open(path, 'r') as json_file:
    life_expectancy = json.load(json_file)

# %%
life_expectancy
# Out:
# [{'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 21.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 22.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 15.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 23.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 21.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 18.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 20.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 19.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 20.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 23.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 20.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 22.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 23.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 18.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 17.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 21.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 22.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 23.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 18.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 22.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 17.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 22.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 20.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 21.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 18.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 21.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 16.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 22.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 21.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y65',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 17.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 83.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 84.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 75.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 85.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 83.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 80.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 83.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 81.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 83.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 86.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 82.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 84.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 85.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 79.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 78.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 84.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 85.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 86.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 79.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 84.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 78.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 84.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 83.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 84.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 79.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 84.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 76.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 85.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 84.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y_LT1',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 78.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 18.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 18.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 11.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 20.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 18.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 14.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 18.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 14.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 17.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 19.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 17.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 18.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 19.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 14.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 13.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 20.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 19.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 21.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 13.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 19.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 12.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 19.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 18.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 19.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 14.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 17.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 12.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 19.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 17.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y65',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 13.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 78.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 79.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 68.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 81.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 79.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 74.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 79.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 72.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 77.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 80.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 77.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 79.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 79.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 73.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 71.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 81.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 80.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 82.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 69.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 80.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 68.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 81.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 79.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 81.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 71.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 78.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 69.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 81.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 77.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'M',
#   'age': 'Y_LT1',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 71.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 19.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 20.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 13.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 21.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 19.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 16.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'DE',
#   'year': 2021,
#   'life_expectancy': 19.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'DE_TOT',
#   'year': 2021,
#   'life_expectancy': 19.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 19.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 17.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 19.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 21.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 19.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 20.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 21.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 16.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 15.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 21.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 20.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 22.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 16.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 20.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 15.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 20.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 19.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 20.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 16.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 19.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 14.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 20.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 19.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y65',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 15.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'AT',
#   'year': 2021,
#   'life_expectancy': 81.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'BE',
#   'year': 2021,
#   'life_expectancy': 81.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'BG',
#   'year': 2021,
#   'life_expectancy': 71.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'CH',
#   'year': 2021,
#   'life_expectancy': 84.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'CY',
#   'year': 2021,
#   'life_expectancy': 81.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'CZ',
#   'year': 2021,
#   'life_expectancy': 77.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'DE',
#   'year': 2021,
#   'life_expectancy': 80.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'DE_TOT',
#   'year': 2021,
#   'life_expectancy': 80.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'DK',
#   'year': 2021,
#   'life_expectancy': 81.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'EE',
#   'year': 2021,
#   'life_expectancy': 76.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'EL',
#   'year': 2021,
#   'life_expectancy': 80.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'ES',
#   'year': 2021,
#   'life_expectancy': 83.3,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'EU27_2020',
#   'year': 2021,
#   'life_expectancy': 80.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'FI',
#   'year': 2021,
#   'life_expectancy': 82.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'FR',
#   'year': 2021,
#   'life_expectancy': 82.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'HR',
#   'year': 2021,
#   'life_expectancy': 76.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'HU',
#   'year': 2021,
#   'life_expectancy': 74.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'IS',
#   'year': 2021,
#   'life_expectancy': 83.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'IT',
#   'year': 2021,
#   'life_expectancy': 82.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'LI',
#   'year': 2021,
#   'life_expectancy': 84.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'LT',
#   'year': 2021,
#   'life_expectancy': 74.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'LU',
#   'year': 2021,
#   'life_expectancy': 82.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'LV',
#   'year': 2021,
#   'life_expectancy': 73.4,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'MT',
#   'year': 2021,
#   'life_expectancy': 82.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'NL',
#   'year': 2021,
#   'life_expectancy': 81.5,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'NO',
#   'year': 2021,
#   'life_expectancy': 83.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'PL',
#   'year': 2021,
#   'life_expectancy': 75.6,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'PT',
#   'year': 2021,
#   'life_expectancy': 81.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'RO',
#   'year': 2021,
#   'life_expectancy': 72.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'SE',
#   'year': 2021,
#   'life_expectancy': 83.2,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'SI',
#   'year': 2021,
#   'life_expectancy': 80.9,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'T',
#   'age': 'Y_LT1',
#   'country': 'SK',
#   'year': 2021,
#   'life_expectancy': 74.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 79.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 82.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 82.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 76.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 84.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 83.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 80.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 82.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 82.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 82.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 83.4,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 83.4,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 82.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 84.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 83.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 84.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'EU27_2020',
#   'year': 2020,
#   'life_expectancy': 82.4,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'FI',
#   'year': 2020,
#   'life_expectancy': 83.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'FR',
#   'year': 2020,
#   'life_expectancy': 84.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'HR',
#   'year': 2020,
#   'life_expectancy': 80.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'HU',
#   'year': 2020,
#   'life_expectancy': 78.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'IE',
#   'year': 2020,
#   'life_expectancy': 83.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'IS',
#   'year': 2020,
#   'life_expectancy': 83.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'IT',
#   'year': 2020,
#   'life_expectancy': 83.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'LI',
#   'year': 2020,
#   'life_expectancy': 82.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'LT',
#   'year': 2020,
#   'life_expectancy': 79.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'LU',
#   'year': 2020,
#   'life_expectancy': 83.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'LV',
#   'year': 2020,
#   'life_expectancy': 79.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 78.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 76.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 83.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 82.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 84.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 80.0,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 83.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 77.7,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 76.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 83.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 82.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y1',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 79.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 70.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 73.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 73.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 68.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 75.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 74.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 71.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 73.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 73.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 73.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 74.5,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 74.4,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 73.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 75.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 74.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 75.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'EU27_2020',
#   'year': 2020,
#   'life_expectancy': 73.5,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'FI',
#   'year': 2020,
#   'life_expectancy': 75.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'FR',
#   'year': 2020,
#   'life_expectancy': 75.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'HR',
#   'year': 2020,
#   'life_expectancy': 71.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'HU',
#   'year': 2020,
#   'life_expectancy': 69.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'IE',
#   'year': 2020,
#   'life_expectancy': 74.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'IS',
#   'year': 2020,
#   'life_expectancy': 74.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'IT',
#   'year': 2020,
#   'life_expectancy': 74.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'LI',
#   'year': 2020,
#   'life_expectancy': 74.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'LT',
#   'year': 2020,
#   'life_expectancy': 70.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'LU',
#   'year': 2020,
#   'life_expectancy': 74.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'LV',
#   'year': 2020,
#   'life_expectancy': 70.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 69.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 67.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 74.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 73.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 75.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 71.0,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 74.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 68.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 67.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 74.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 73.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y10',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 70.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 69.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 72.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 72.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 67.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 74.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 73.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 70.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 72.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 72.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 72.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 73.5,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 73.4,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 72.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 74.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 73.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 74.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'EU27_2020',
#   'year': 2020,
#   'life_expectancy': 72.5,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'FI',
#   'year': 2020,
#   'life_expectancy': 74.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'FR',
#   'year': 2020,
#   'life_expectancy': 74.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'HR',
#   'year': 2020,
#   'life_expectancy': 70.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'HU',
#   'year': 2020,
#   'life_expectancy': 68.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'IE',
#   'year': 2020,
#   'life_expectancy': 73.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'IS',
#   'year': 2020,
#   'life_expectancy': 73.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'IT',
#   'year': 2020,
#   'life_expectancy': 73.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'LI',
#   'year': 2020,
#   'life_expectancy': 73.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'LT',
#   'year': 2020,
#   'life_expectancy': 69.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'LU',
#   'year': 2020,
#   'life_expectancy': 73.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'LV',
#   'year': 2020,
#   'life_expectancy': 69.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 68.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 66.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 73.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 72.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 74.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 70.0,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 73.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 67.8,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 66.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 73.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 72.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y11',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 69.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 68.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 72.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 71.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 66.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 73.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 72.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 69.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 71.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 71.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 71.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y12',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 72.5,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
# ...
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 54.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 52.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 60.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 60.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 56.2,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 59.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 54.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 53.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 59.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y25',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 56.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 54.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 58.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 57.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 52.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 59.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 58.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 55.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 58.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 58.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 58.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 57.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 59.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 58.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 59.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'EU27_2020',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'FI',
#   'year': 2020,
#   'life_expectancy': 59.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'FR',
#   'year': 2020,
#   'life_expectancy': 59.8,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'HR',
#   'year': 2020,
#   'life_expectancy': 55.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'HU',
#   'year': 2020,
#   'life_expectancy': 53.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'IE',
#   'year': 2020,
#   'life_expectancy': 58.8,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'IS',
#   'year': 2020,
#   'life_expectancy': 58.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'IT',
#   'year': 2020,
#   'life_expectancy': 58.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'LI',
#   'year': 2020,
#   'life_expectancy': 59.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'LT',
#   'year': 2020,
#   'life_expectancy': 54.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'LU',
#   'year': 2020,
#   'life_expectancy': 59.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'LV',
#   'year': 2020,
#   'life_expectancy': 54.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 53.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 51.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 59.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 59.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 55.2,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 58.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 53.0,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 52.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y26',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 55.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 53.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 57.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 56.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 51.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 58.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 57.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 54.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 57.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 57.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 57.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 56.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 58.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 57.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 58.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'EU27_2020',
#   'year': 2020,
#   'life_expectancy': 56.6,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'FI',
#   'year': 2020,
#   'life_expectancy': 58.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'FR',
#   'year': 2020,
#   'life_expectancy': 58.8,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'HR',
#   'year': 2020,
#   'life_expectancy': 54.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'HU',
#   'year': 2020,
#   'life_expectancy': 52.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'IE',
#   'year': 2020,
#   'life_expectancy': 57.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'IS',
#   'year': 2020,
#   'life_expectancy': 57.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'IT',
#   'year': 2020,
#   'life_expectancy': 57.9,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'LI',
#   'year': 2020,
#   'life_expectancy': 58.2,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'LT',
#   'year': 2020,
#   'life_expectancy': 53.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'LU',
#   'year': 2020,
#   'life_expectancy': 58.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'LV',
#   'year': 2020,
#   'life_expectancy': 53.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'ME',
#   'year': 2020,
#   'life_expectancy': 52.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'MK',
#   'year': 2020,
#   'life_expectancy': 50.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'MT',
#   'year': 2020,
#   'life_expectancy': 58.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'NL',
#   'year': 2020,
#   'life_expectancy': 56.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'NO',
#   'year': 2020,
#   'life_expectancy': 58.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'PL',
#   'year': 2020,
#   'life_expectancy': 54.2,
#   'flag': 'ep',
#   'flag_detail': 'estimated, provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'PT',
#   'year': 2020,
#   'life_expectancy': 57.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'RO',
#   'year': 2020,
#   'life_expectancy': 52.1,
#   'flag': 'e',
#   'flag_detail': 'estimated'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'RS',
#   'year': 2020,
#   'life_expectancy': 51.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'SE',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'SI',
#   'year': 2020,
#   'life_expectancy': 56.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y27',
#   'country': 'SK',
#   'year': 2020,
#   'life_expectancy': 54.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'AL',
#   'year': 2020,
#   'life_expectancy': 52.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'AT',
#   'year': 2020,
#   'life_expectancy': 56.1,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'BE',
#   'year': 2020,
#   'life_expectancy': 55.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'BG',
#   'year': 2020,
#   'life_expectancy': 50.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'CH',
#   'year': 2020,
#   'life_expectancy': 57.6,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'CY',
#   'year': 2020,
#   'life_expectancy': 56.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'CZ',
#   'year': 2020,
#   'life_expectancy': 53.7,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'DE',
#   'year': 2020,
#   'life_expectancy': 56.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'DE_TOT',
#   'year': 2020,
#   'life_expectancy': 56.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'DK',
#   'year': 2020,
#   'life_expectancy': 56.0,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'EA18',
#   'year': 2020,
#   'life_expectancy': 56.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'EA19',
#   'year': 2020,
#   'life_expectancy': 56.6,
#   'flag': 'p',
#   'flag_detail': 'provisional'},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'EE',
#   'year': 2020,
#   'life_expectancy': 55.4,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'EFTA',
#   'year': 2020,
#   'life_expectancy': 57.5,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'EL',
#   'year': 2020,
#   'life_expectancy': 56.3,
#   'flag': '',
#   'flag_detail': None},
#  {'unit': 'YR',
#   'sex': 'F',
#   'age': 'Y28',
#   'country': 'ES',
#   'year': 2020,
#   'life_expectancy': 57.5,
#   'flag': '',
#   'flag_detail': None},
#  ...]
